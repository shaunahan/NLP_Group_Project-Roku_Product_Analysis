# %%
import nltk
nltk.download('stopwords')

import numpy as np
import pandas as pd
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# !pip install langdetect
# Out:
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      |████████████████████████████████| 981 kB 4.3 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from langdetect) (1.15.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993242 sha256=86004acbcf478366671d74dc7a6c2d62ed8f1abf08e0aec454fbbe5cde1de987
#   Stored in directory: /root/.cache/pip/wheels/c5/96/8a/f90c59ed25d75e50a8c10a1b1c2d4c402e4dacfa87f3aff36a
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9

# %% [markdown]
# #OS version 9.4

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('/content/drive/My Drive/NLP_Project/LDA data/amazon data')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df= pd.read_csv('amazon_OS94.csv')

# %%
df
# Out:
#      Unnamed: 0  Unnamed: 0.1              id  \
# 0          1005          1005   RC0VUELJ5J21Z
# 1          1006          1006  R2SQ3VE76MFD77
# 2          1007          1007   RP1JOT9J32351
# 3          1008          1008   RWU9G50GRAE2G
# 4          1009          1008  R39YWYM402IOAH
# ..          ...           ...             ...
# 704        1709          1708  R3P8VTUWBT3VRI
# 705        1710          1710   RPMRAIK4R24PD
# 706        1711          1711  R2XT1VPCB1O9W0
# 707        1712          1712   RFE3DJ7EAQZDO
# 708        1713          1713  R2J7CMIOHAPP2F
#
#                                title  \
# 0            Credit Card Requirement
# 1                               Ruko
# 2                Fabulous product!!!
# 3                 Better than cable!
# 4                           Love It!
# ..                               ...
# 704  Ruined by latest sofware update
# 705                 Excelente compra
# 706                        Excellent
# 707                            Happy
# 708                     Not So Ultra
#
#                                                   body  \
# 0    Roku's requirement that customers must provide...
# 1    I have no complaints. It way better than the l...
# 2    Fabulous product!! Works so well we bought a s...
# 3    I feel we waited way to long to cut the cable ...
# 4    I recently upgraded my tv to 4K. I’ve always h...
# ..                                                 ...
# 704  My Roku Ultra is making a popping sound since ...
# 705  Gran variedad de contenido. Se mueve muy rápid...
# 706  Replacing the entrance level 4k Roku. Truly an...
# 707  Ordered this for my son?!!!! He says it fantas...
# 708  Runs great as far as app compatibility and spe...
#
#                                                   link  rating  \
# 0    https://www.amazon.com/gp/customer-reviews/RC0...       1
# 1    https://www.amazon.com/gp/customer-reviews/R2S...       5
# 2    https://www.amazon.com/gp/customer-reviews/RP1...       5
# 3    https://www.amazon.com/gp/customer-reviews/RWU...       5
# 4    https://www.amazon.com/gp/customer-reviews/R39...       5
# ..                                                 ...     ...
# 704  https://www.amazon.com/gp/customer-reviews/R3P...       1
# 705  https://www.amazon.com/gp/customer-reviews/RPM...       5
# 706  https://www.amazon.com/gp/customer-reviews/R2X...       5
# 707  https://www.amazon.com/gp/customer-reviews/RFE...       5
# 708  https://www.amazon.com/gp/customer-reviews/R2J...       3
#
#      verified_purchase  helpful_votes  year  month   version  \
# 0                 True            NaN  2021      4  O.S. 9.4
# 1                 True            NaN  2021      4  O.S. 9.4
# 2                 True            NaN  2021      4  O.S. 9.4
# 3                 True            NaN  2021      4  O.S. 9.4
# 4                 True            NaN  2021      4  O.S. 9.4
# ..                 ...            ...   ...    ...       ...
# 704              False            3.0  2020     12  O.S. 9.4
# 705               True            NaN  2020     12  O.S. 9.4
# 706               True            NaN  2020     12  O.S. 9.4
# 707               True            NaN  2020     12  O.S. 9.4
# 708               True            NaN  2020     12  O.S. 9.4
#
#                                             bd_cleaned  \
# 0    do not buy this product ours ran great for mon...
# 1    i purchased this roku as i wanted to see if i ...
# 2    it really beats the roku hdmi sticks doesn t o...
# 3    i love roku but it reboots if it is not used i...
# 4    the device is as great as all roku s are but r...
# ..                                                 ...
# 704  the mute didn t work lip sync was off on movie...
# 705  i replaced my roku to be able to do atmos dolb...
# 706  i got this new roku unit specifically so that ...
# 707  returned because picture kept cutting out and ...
# 708  i ordered my ultra directly from roku as amazo...
#
#                                             sw_removed  \
# 0    buy product ran great months stopped working c...
# 1    purchased wanted see would able cut satellite ...
# 2    really beats hdmi sticks heat keeps larger buf...
# 3                              love reboots used hours
# 4    device great go f even letting use blasted thi...
# ..                                                 ...
# 704  mute work lip sync movies shows would restart ...
# 705  replaced able atmos dolby vision know unit ups...
# 706  got new unit specifically could connect blueto...
# 707  returned picture kept cutting support repeated...
# 708  ordered ultra directly back ordered arrived oc...
#
#                                                stemmed
# 0    buy product ran great month stop work custom s...
# 1    purchas want see would abl cut satellit cabl u...
# 2    realli beat hdmi stick heat keep larger buffer...
# 3                                 love reboot use hour
# 4    devic great go f even let use blast thing ente...
# ..                                                 ...
# 704  mute work lip sync movi show would restart get...
# 705  replac abl atmo dolbi vision know unit upscal ...
# 706  got new unit specif could connect bluetooth he...
# 707  return pictur kept cut support repeat themself...
# 708  order ultra directli back order arriv oct th o...
#
# [709 rows x 15 columns]

# %%
df['body'] = df['body'].replace(np.nan, '')

# %%
import re
def cleaner(text):
    return re.sub("^[a-zA_Z0-9]+", " ", text).strip().lower()


df["cleaned_bd"]=df["body"].apply(cleaner).to_list()

# remove stop words 
def stop_word_remove(i):
    from nltk.corpus import stopwords
    stops=stopwords.words("english")
    stops.extend(['from', 'subject', 're', 'edu', 'use', 'https', 'roku', 'amp', 'co'])
    ret=[w for w in i.split() if w not in stops]
    return " ".join(ret)

# %%
df["final"]=df["cleaned_bd"].apply(stop_word_remove)

new_dataframe = df["final"].tolist()

# %%
#wordcloud

import nltk
from nltk import word_tokenize
from nltk.probability import FreqDist
import urllib.request
from matplotlib import pyplot as plt
from wordcloud import WordCloud
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def show_wordcloud(data):
    stopwords = nltk.corpus.stopwords.words('english')
    stopwords.append('https')
    stopwords.extend(['roku', 'co', 'tv', 'app', 'amp'])
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        max_words=300,
        max_font_size=50,
        scale=3,
        random_state = 1,
        collocations=False)
   
    wordcloud=wordcloud.generate(str(new_dataframe))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')

    plt.imshow(wordcloud)
    plt.show()

show_wordcloud(new_dataframe)

# %% [markdown]
# ## 10 popular words: romote, work, would, device, streaming, ultra, great, one, easy, like

# %% [markdown]
# # OS version 10

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('/content/drive/My Drive/NLP_Project/LDA data/amazon data')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df= pd.read_csv('amazon_OS10.csv')

# %%
df['body'] = df['body'].replace(np.nan, '')

import re
def cleaner(text):
    return re.sub("^[a-zA_Z0-9]+", " ", text).strip().lower()


df["cleaned_bd"]=df["body"].apply(cleaner).to_list()

# remove stop words 
def stop_word_remove(i):
    from nltk.corpus import stopwords
    stops=stopwords.words("english")
    stops.extend(['from', 'subject', 're', 'edu', 'use', 'https', 'roku', 'amp', 'co'])
    ret=[w for w in i.split() if w not in stops]
    return " ".join(ret)

df["final"]=df["cleaned_bd"].apply(stop_word_remove)

new_dataframe1 = df["final"].tolist()

# %%
def show_wordcloud(data):
    stopwords = nltk.corpus.stopwords.words('english')
    stopwords.append('https')
    stopwords.extend(['roku', 'co', 'tv', 'app', 'amp'])
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        max_words=300,
        max_font_size=50,
        scale=3,
        random_state = 1,
        collocations=False)
   
    wordcloud=wordcloud.generate(str(new_dataframe1))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')

    plt.imshow(wordcloud)
    plt.show()

show_wordcloud(new_dataframe1)

# %% [markdown]
# ## 10 popular words: ultra, remote, great, device, streaming, love, like, one, work, get, button

# %% [markdown]
# #OS vrsion 10.5

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('/content/drive/My Drive/NLP_Project/LDA data/amazon data')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df= pd.read_csv('amazon_OS10_5.csv')

# %%
df['body'] = df['body'].replace(np.nan, '')

import re
def cleaner(text):
    return re.sub("^[a-zA_Z0-9]+", " ", text).strip().lower()


df["cleaned_bd"]=df["body"].apply(cleaner).to_list()

# remove stop words 
def stop_word_remove(i):
    from nltk.corpus import stopwords
    stops=stopwords.words("english")
    stops.extend(['from', 'subject', 're', 'edu', 'use', 'https', 'roku', 'amp', 'co'])
    ret=[w for w in i.split() if w not in stops]
    return " ".join(ret)

df["final"]=df["cleaned_bd"].apply(stop_word_remove)

new_dataframe2 = df["final"].tolist()

# %%
def show_wordcloud(data):
    stopwords = nltk.corpus.stopwords.words('english')
    stopwords.append('https')
    stopwords.extend(['roku', 'co', 'tv', 'app', 'amp', 'amazon', 'youtube'])
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        max_words=300,
        max_font_size=50,
        scale=3,
        random_state = 1,
        collocations=False)
   
    wordcloud=wordcloud.generate(str(new_dataframe2))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')

    plt.imshow(wordcloud)
    plt.show()

show_wordcloud(new_dataframe2)

# %% [markdown]
# ## 10 popular words: remote, device, work, streaming, ultra, time, get, issue, great, one
